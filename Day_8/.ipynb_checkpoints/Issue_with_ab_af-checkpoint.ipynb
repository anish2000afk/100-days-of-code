# %% [markdown]
# ![image.png](attachment:b80991f3-7718-4815-99f2-eda7fd3f367e.png)

# %% [markdown]
# The shift varialbe is remains negative after the first instance.\
# Making it positive on the second run, resulting in a +5 and hence an "f".\
# To solve this we just move it outside the for loop.
